# %% [markdown]
# # 非线性规划

# %% [markdown]
# 目标函数/约束条件中包含非线性函数

# %%
import matplotlib.pyplot as plt
from scipy import optimize
import numpy as np

# %% [markdown]
# # 1. 非线性规划的标准形式

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. 非线性规划的代码实现

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. 无约束极值问题求解
